# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
# loading the data
df =  pd.read_csv(r'heart.dat', sep=" ", header=None)
column_name = ['age', 'sex', 'chest pain', 'resting blood pressure', 'serum cholestoral', 'fasting blood sugar', 'resting electrocardiographic', 'maximum heart rate achieved',' exercise induced angina', 'oldpeak',' the slope of the peak exercise ST segment', 'number of major vessels', 'tha', 'label']

df.columns = column_name
df = df.fillna(0)

df.describe(include="all")
# Out:
#               age         sex  chest pain  resting blood pressure  \
# count  270.000000  270.000000  270.000000              270.000000
# mean    54.433333    0.677778    3.174074              131.344444
# std      9.109067    0.468195    0.950090               17.861608
# min     29.000000    0.000000    1.000000               94.000000
# 25%     48.000000    0.000000    3.000000              120.000000
# 50%     55.000000    1.000000    3.000000              130.000000
# 75%     61.000000    1.000000    4.000000              140.000000
# max     77.000000    1.000000    4.000000              200.000000
#
#        serum cholestoral  fasting blood sugar  resting electrocardiographic  \
# count         270.000000           270.000000                    270.000000
# mean          249.659259             0.148148                      1.022222
# std            51.686237             0.355906                      0.997891
# ...

# %%
print("1 = Without heart disease and 2 = With heart disease")
print(df.groupby("label").size()*100/270)
# Out:
# 1 = Without heart disease and 2 = With heart disease
# label
# 1    55.555556
# 2    44.444444
# dtype: float64

# %%
# loading the data
df =  pd.read_csv(r'diabetes2.csv', sep=",", header=0)
column_name = ['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age','Outcome']

df.columns = column_name
df = df.fillna(0)

df.describe(include="all")
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
print("0 = Without Diabetes disease and 1 = With Diabetes disease")
print(df.groupby("Outcome").size()*100/768)
# Out:
# 0 = Without Diabetes disease and 1 = With Diabetes disease
# Outcome
# 0    65.104167
# 1    34.895833
# dtype: float64
